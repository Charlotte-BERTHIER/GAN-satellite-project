# %% [markdown]
# ## Classification supervisée des images
#
# Un réseau de neurones est-il en mesure de détecter les armures des tissages ?

# %%
import pandas as pd
import os
import numpy as np
import shutil #copier fichier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from PIL import Image
import cv2

import random

# %%
data = '../data'

# %%
os.chdir(data)

# %%
from ultralytics import YOLO

# %% [markdown]
# ### Création du dataset

# %%
#CREATION DOSSIER D'IMAGES VRAIES
def copy_random_images(source_dir, dest_dir, num_images):
    # Vérification et création du dossier de destination
    if not os.path.exists(dest_dir):
        os.makedirs(dest_dir)

    # Liste des images dans le dossier source
    images = [f for f in os.listdir(source_dir) if os.path.isfile(os.path.join(source_dir, f))]

    # Vérification du nombre d'images disponibles
    if len(images) < num_images:
        raise ValueError("Le dossier source ne contient pas suffisamment d'images.")

    # Sélection aléatoire des images
    selected_images = random.sample(images, num_images)

    # Copier les images sélectionnées vers le dossier de destination
    for image in selected_images:
        src_path = os.path.join(source_dir, image)
        dst_path = os.path.join(dest_dir, image)
        shutil.copyfile(src_path, dst_path)

# %%
# Exemple d'utilisation
source_dir = 'dataset_double'
dest_dir = 'yolo/vrai'
copy_random_images(source_dir, dest_dir, 212)

# %%
def split_and_save_images(source_dir):
    for image_name in os.listdir(source_dir):
        image_path = os.path.join(source_dir, image_name)
        
        if os.path.isfile(image_path) and image_name.lower().endswith('.jpg'):
            with Image.open(image_path) as img:
                width, height = img.size
                img_sat = img.crop((0, 0, width // 2, height))

                # Sauvegarder les deux moitiés en écrasant l'image originale
                img_sat.save(image_path)

# %%
# Exemple d'utilisation
split_and_save_images('yolo/vrai')

# %% [markdown]
# ### Téléchargement du modèle et visualisation de ses composantes

# %%
#Version YOLOv8
model = YOLO('yolov8n-cls')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n-cls.pt to 'yolov8n-cls.pt'...
# 100%|██████████████████████████████████████| 5.30M/5.30M [00:01<00:00, 4.68MB/s]

# %%
#Version YOLOv8
model
# Out:
# YOLO(
#   (model): ClassificationModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (3): Conv(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (4): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (5): Conv(
#         (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (6): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (7): Conv(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (8): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (9): Classify(
#         (conv): Conv(
#           (conv): Conv2d(256, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (pool): AdaptiveAvgPool2d(output_size=1)
#         (drop): Dropout(p=0.0, inplace=True)
#         (linear): Linear(in_features=1280, out_features=1000, bias=True)
#       )
#     )
#   )
# )

# %% [markdown]
# ### Partage des données train/test

# %%
yolo = "yolo"
os.makedirs(yolo, exist_ok=True)

# %%
dataset_dir = data
train_dir = 'yolo/train'
val_dir = 'yolo/val'

# %%
faux_test = "GAN/predicted_images106_test"
faux_val = "GAN/predicted_images106_val"
faux_dir = 'yolo/faux'
os.makedirs(faux_dir, exist_ok=True)

# %%
# Create the destination folder if it doesn't exist
if not os.path.exists(faux_dir):
    os.makedirs(faux_dir)

# Copy the contents of the first folder to the destination folder
for item in os.listdir(faux_test):
    source_path = os.path.join(faux_test, item)
    destination_path = os.path.join(faux_dir, item)
    if os.path.isdir(source_path):
        shutil.copytree(source_path, destination_path, dirs_exist_ok=True)
    else:
        shutil.copy2(source_path, destination_path)

# Copy the contents of the second folder to the destination folder
for item in os.listdir(faux_val):
    source_path = os.path.join(faux_val, item)
    destination_path = os.path.join(faux_dir, f"V_{item}")
    if os.path.isdir(source_path):
        shutil.copytree(source_path, destination_path, dirs_exist_ok=True)
    else:
        shutil.copy2(source_path, destination_path)

# %%
class_folders = [dir for dir in os.listdir(yolo) if os.path.isdir(os.path.join(yolo, dir))]
#On récupère la listes des noms des dossiers/classes

# %%
class_folders
# Out:
# ['vrai', 'faux']

# %% [markdown]
# ### Entraînement des données

# %%
for original_folder in class_folders:
  if original_folder == "vrai" or original_folder == "faux":

    old_path  = os.path.join(yolo, original_folder) #concaténation chemin et nom du dossier
    new_folder_name = original_folder.split('-')[0]
    new_path = os.path.join(yolo, new_folder_name) #creation nouveau chemin

    os.rename(old_path, new_path)

# %%
#Pour répartir les images d'entraînement et de validation dans des dossiers avec le bon nom
for class_folder in class_folders:
    if class_folder == "vrai" or class_folder == "faux":

      class_path = os.path.join(yolo, class_folder)
      images = [image for image in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, image))]

      train_img, val_img = train_test_split(images, test_size=0.2, random_state=42)

      train_subfolder_path = os.path.join(train_dir, class_folder)
      val_subfolder_path = os.path.join(val_dir, class_folder)

      os.makedirs(train_subfolder_path, exist_ok=True)
      os.makedirs(val_subfolder_path, exist_ok=True)

      for img in train_img:
        shutil.copy(os.path.join(class_path, img), train_subfolder_path)

      for img in val_img:
        shutil.copy(os.path.join(class_path, img), val_subfolder_path)

# %%
###### Version pour YOLOv8
results = model.train(data='yolo',
                      epochs=10,
                      batch=32,
                      dropout=0.1,
                      seed = 42)
                     ,#device='mps') #Entrainement sur la puce Apple M2 (et M1) "Metal Performance Shaders"

#Bug. en utilisant MPS: error: 'mps.select' op failed to verify that all of {true_value, false_value, result} have same element type
    # note: see current operation: %17 = "mps.select"(%16, %15, %14) : (tensor<1xi1>, tensor<1xf16>, tensor<1xf32>) -> tensor<1xf16>
    #failed assertion 'expected a valid model URL'
#Pas encore solutionné par Ultralytics : https://github.com/ultralytics/ultralytics/issues/7554 (issue du 13 janvier 2024).
# Out:
# New https://pypi.org/project/ultralytics/8.2.31 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.18 🚀 Python-3.11.9 torch-2.2.2 CPU (Apple M2)
# engine/trainer: task=classify, mode=train, model=yolov8n-cls.pt, data=/Users/lise/Python/projet/data/yolo, epochs=10, time=None, patience=100, batch=32, imgsz=224, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train4, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=42, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.1, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/classify/train4
# train: /Users/lise/Python/projet/data/yolo/train... found 338 images in 2 classes ✅
# val: /Users/lise/Python/projet/data/yolo/val... found 86 images in 2 classes ✅
# test: None...
# Overriding model.yaml nc=1000 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    332802  ultralytics.nn.modules.head.Classify         [256, 2]
# YOLOv8n-cls summary: 99 layers, 1440850 parameters, 1440850 gradients, 3.4 GFLOPs
# Transferred 156/158 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/classify/train4', view at http://localhost:6006/
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# train: Scanning /Users/lise/Python/projet/data/yolo/train... 338 images, 0 corru
# train: New cache created: /Users/lise/Python/projet/data/yolo/train.cache
# val: Scanning /Users/lise/Python/projet/data/yolo/val... 86 images, 0 corrupt: 1
# val: New cache created: /Users/lise/Python/projet/data/yolo/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 224 train, 224 val
# Using 0 dataloader workers
# Logging results to runs/classify/train4
# Starting training for 10 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/10         0G     0.7101         18        224: 100%|██████████| 11/11
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,
#                    all      0.512          1
#       Epoch    GPU_mem       loss  Instances       Size
#        2/10         0G     0.5721         18        224: 100%|██████████| 11/11
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,
#                    all      0.919          1
#       Epoch    GPU_mem       loss  Instances       Size
#        3/10         0G     0.3929         18        224: 100%|██████████| 11/11
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,
#                    all      0.965          1
#       Epoch    GPU_mem       loss  Instances       Size
#        4/10         0G     0.2313         18        224: 100%|██████████| 11/11
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,
#                    all      0.988          1
#       Epoch    GPU_mem       loss  Instances       Size
#        5/10         0G     0.1407         18        224: 100%|██████████| 11/11
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,
#                    all      0.988          1
#       Epoch    GPU_mem       loss  Instances       Size
#        6/10         0G    0.09458         18        224: 100%|██████████| 11/11
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,
#                    all          1          1
#       Epoch    GPU_mem       loss  Instances       Size
#        7/10         0G    0.08137         18        224: 100%|██████████| 11/11
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,
#                    all          1          1
#       Epoch    GPU_mem       loss  Instances       Size
#        8/10         0G    0.05429         18        224: 100%|██████████| 11/11
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,
#                    all          1          1
#       Epoch    GPU_mem       loss  Instances       Size
#        9/10         0G    0.05722         18        224: 100%|██████████| 11/11
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,
#                    all          1          1
#       Epoch    GPU_mem       loss  Instances       Size
#       10/10         0G    0.05257         18        224: 100%|██████████| 11/11
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,
#                    all          1          1
# 10 epochs completed in 0.057 hours.
# Optimizer stripped from runs/classify/train4/weights/last.pt, 3.0MB
# Optimizer stripped from runs/classify/train4/weights/best.pt, 3.0MB
#
# Validating runs/classify/train4/weights/best.pt...
# Ultralytics YOLOv8.2.18 🚀 Python-3.11.9 torch-2.2.2 CPU (Apple M2)
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
# train: /Users/lise/Python/projet/data/yolo/train... found 338 images in 2 classes ✅
# val: /Users/lise/Python/projet/data/yolo/val... found 86 images in 2 classes ✅
# test: None...
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,
#                    all          1          1
# Speed: 0.0ms preprocess, 8.1ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/train4
# Results saved to runs/classify/train4

# %%
my_model = YOLO('runs/classify/train4/weights/best.pt')

# %%
#Visualisation des résultats du modèle = résultat
result = my_model('yolo/val/faux/predicted_image_40.png', visualize=True, save=True)
#En jaune on voir les zones maximisées par neurones (pooling = plus on avance dans les couches moins on a de pixels)
#Intéressant pour comprendre les choix de classification d'un réseau (couleur, motif, background...)
# Out:
# Saving runs/classify/predict3/predicted_image_40/stage0_Conv_features.png... (16/16)
# Saving runs/classify/predict3/predicted_image_40/stage1_Conv_features.png... (32/32)
# Saving runs/classify/predict3/predicted_image_40/stage2_C2f_features.png... (32/32)
# Saving runs/classify/predict3/predicted_image_40/stage3_Conv_features.png... (32/64)
# Saving runs/classify/predict3/predicted_image_40/stage4_C2f_features.png... (32/64)
# Saving runs/classify/predict3/predicted_image_40/stage5_Conv_features.png... (32/128)
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# Saving runs/classify/predict3/predicted_image_40/stage6_C2f_features.png... (32/128)
# Saving runs/classify/predict3/predicted_image_40/stage7_Conv_features.png... (32/256)
# Saving runs/classify/predict3/predicted_image_40/stage8_C2f_features.png... (32/256)
# image 1/1 /Users/lise/Python/GAN-satellite-project/data/yolo/val/faux/predicted_image_40.png: 224x224 faux 1.00, vrai 0.00, 12648.2ms
# Speed: 64.9ms preprocess, 12648.2ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict3

# %% [markdown]
# ### Tentative de compréhension des _features_
# Méthode de l'occlusion.

# %%
occlusion = "yolo/occlusion"
os.makedirs(occlusion, exist_ok=True)

# %%
def generate_occlusion(image, model, class_id,occlusion_size,step_size):
    #initialisation des valeurs
    image_height, image_width , _ = image.shape
    heatmap=np.zeros((image_height,image_width))
    
    predict_model=YOLO(model)
    results=predict_model.predict(image)

    #YOLO me sort 4 informations top1 id , top1conf, top5 id , top5conf. 
    #Il faut s'assurer que la classe id est dans le top 1 et dans le cas échéant ou dans le top5 (avec la proba associée)

    if class_id in results[0].probs.top5 :
        rank = results[0].probs.top5.index(class_id)
        initial_confidence=results[0].probs.top5conf[rank]
    else : 
        initial_confidence=0
    

    for y in range(0,image_width - occlusion_size[1] + 1, step_size) : #on oublie pas de commencer à 0, à cause du pas
        for x in range(0,image_height - occlusion_size[0] + 1, step_size) : 
            print(y,x) #Permet de voir l'avancée de l'occlusion
            
            occluded_image=image.copy()
            occluded_image[x:x + occlusion_size[0],y:y + occlusion_size[1]] = 0 

            results=predict_model.predict(occluded_image)

            if class_id in results[0].probs.top5 :
                rank = results[0].probs.top5.index(class_id)
                class_confidence=results[0].probs.top5conf[rank]
            else : 
                class_confidence = 0

            heatmap[x:x + occlusion_size[0],y:y + occlusion_size[1]] = initial_confidence - class_confidence

    heatmap=(heatmap-np.min(heatmap)/np.max(heatmap) - np.min(heatmap))

    return heatmap

# %%
def get_random_image(source_dir, num_images):
    
    # Liste des images dans le dossier source
    images = [f for f in os.listdir(source_dir) if os.path.isfile(os.path.join(source_dir, f))]

    # Vérification du nombre d'images disponibles
    if len(images) < num_images:
        raise ValueError("Le dossier source ne contient pas suffisamment d'images.")

    # Sélection aléatoire des images
    selected_images = random.sample(images, num_images)

    list_path = []

    for im in selected_images :
        list_path.append(os.path.join(source_dir, im))
        
    return list_path

# %%
get_random_image('yolo/val/faux/',5)
# Out:
# ['/Users/lise/Python/projet/data/yolo/val/faux/predicted_image_51.png',
#  '/Users/lise/Python/projet/data/yolo/val/faux/predicted_image_63.png',
#  '/Users/lise/Python/projet/data/yolo/val/faux/predicted_image_40.png',
#  '/Users/lise/Python/projet/data/yolo/val/faux/V_predicted_image_48.png',
#  '/Users/lise/Python/projet/data/yolo/val/faux/predicted_image_76.png']

# %%
for image_path in get_random_image('yolo/val/faux/', 5) : 
    image=cv2.imread(image_path,cv2.IMREAD_COLOR)
    heatmap=generate_occlusion(image,'runs/classify/train4/weights/best.pt',0,(5,5),5)
    overlay_image=overlay_heatmap(image,heatmap)
    cv2.imwrite(f'occlusion/occlusion_{image_path.split("/")[-1]}',overlay_image)
# Out:
# 0: 224x224 faux 1.00, vrai 0.00, 98.2ms
# Speed: 79.5ms preprocess, 98.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 0 0
#
# 0: 224x224 faux 1.00, vrai 0.00, 21.4ms
# Speed: 2.5ms preprocess, 21.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 5
#
# 0: 224x224 faux 1.00, vrai 0.00, 20.0ms
# Speed: 3.4ms preprocess, 20.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 10
#
# 0: 224x224 faux 1.00, vrai 0.00, 18.0ms
# Speed: 2.8ms preprocess, 18.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 15
#
# 0: 224x224 faux 1.00, vrai 0.00, 16.3ms
# Speed: 3.1ms preprocess, 16.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 20
#
# 0: 224x224 faux 1.00, vrai 0.00, 16.9ms
# Speed: 2.9ms preprocess, 16.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 25
#
# 0: 224x224 faux 1.00, vrai 0.00, 15.6ms
# Speed: 2.4ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 30
#
# 0: 224x224 faux 1.00, vrai 0.00, 17.6ms
# Speed: 2.4ms preprocess, 17.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 35
#
# 0: 224x224 faux 1.00, vrai 0.00, 16.3ms
# Speed: 2.6ms preprocess, 16.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 40
#
# 0: 224x224 faux 1.00, vrai 0.00, 16.1ms
# Speed: 2.4ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 45
#
# 0: 224x224 faux 1.00, vrai 0.00, 16.0ms
# Speed: 2.8ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 50
#
# 0: 224x224 faux 1.00, vrai 0.00, 17.6ms
# Speed: 2.9ms preprocess, 17.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 55
#
# 0: 224x224 faux 1.00, vrai 0.00, 18.2ms
# Speed: 2.2ms preprocess, 18.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 60
#
# 0: 224x224 faux 1.00, vrai 0.00, 17.4ms
# Speed: 2.4ms preprocess, 17.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 65
#
# 0: 224x224 faux 1.00, vrai 0.00, 16.3ms
# Speed: 2.2ms preprocess, 16.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 70
#
# 0: 224x224 faux 1.00, vrai 0.00, 16.8ms
# Speed: 2.6ms preprocess, 16.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 75
#
# 0: 224x224 faux 1.00, vrai 0.00, 22.5ms
# Speed: 2.7ms preprocess, 22.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 80
#
# 0: 224x224 faux 1.00, vrai 0.00, 25.0ms
# Speed: 2.9ms preprocess, 25.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 85
#
# 0: 224x224 faux 1.00, vrai 0.00, 26.3ms
# Speed: 3.8ms preprocess, 26.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 90
#
# 0: 224x224 faux 1.00, vrai 0.00, 19.8ms
# Speed: 4.8ms preprocess, 19.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 95
#
# 0: 224x224 faux 1.00, vrai 0.00, 19.6ms
# Speed: 2.5ms preprocess, 19.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 100
#
# 0: 224x224 faux 1.00, vrai 0.00, 18.1ms
# Speed: 3.1ms preprocess, 18.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 105
#
# 0: 224x224 faux 1.00, vrai 0.00, 17.6ms
# Speed: 2.3ms preprocess, 17.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 110
#
# 0: 224x224 faux 1.00, vrai 0.00, 19.2ms
# Speed: 2.7ms preprocess, 19.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 115
#
# 0: 224x224 faux 1.00, vrai 0.00, 17.9ms
# Speed: 2.6ms preprocess, 17.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 120
#
# 0: 224x224 faux 1.00, vrai 0.00, 21.9ms
# Speed: 2.9ms preprocess, 21.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 125
#
# 0: 224x224 faux 1.00, vrai 0.00, 18.6ms
# Speed: 3.2ms preprocess, 18.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 130
#
# 0: 224x224 faux 1.00, vrai 0.00, 19.7ms
# Speed: 2.6ms preprocess, 19.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 135
#
# 0: 224x224 faux 1.00, vrai 0.00, 20.1ms
# Speed: 2.7ms preprocess, 20.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 140
#
# 0: 224x224 faux 1.00, vrai 0.00, 21.1ms
# Speed: 4.1ms preprocess, 21.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 145
#
# 0: 224x224 faux 1.00, vrai 0.00, 20.6ms
# Speed: 2.7ms preprocess, 20.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 150
#
# 0: 224x224 faux 1.00, vrai 0.00, 18.5ms
# Speed: 2.7ms preprocess, 18.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 155
#
# 0: 224x224 faux 1.00, vrai 0.00, 18.2ms
# Speed: 2.7ms preprocess, 18.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 160
#
# 0: 224x224 faux 1.00, vrai 0.00, 18.8ms
# Speed: 2.8ms preprocess, 18.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 165
#
# 0: 224x224 faux 1.00, vrai 0.00, 20.4ms
# Speed: 2.9ms preprocess, 20.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 170
#
# 0: 224x224 faux 1.00, vrai 0.00, 19.9ms
# Speed: 3.3ms preprocess, 19.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 175
#
# 0: 224x224 faux 1.00, vrai 0.00, 20.1ms
# Speed: 3.1ms preprocess, 20.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 180
#
# 0: 224x224 faux 1.00, vrai 0.00, 24.2ms
# Speed: 4.2ms preprocess, 24.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 185
#
# 0: 224x224 faux 1.00, vrai 0.00, 27.4ms
# Speed: 4.7ms preprocess, 27.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 190
#
# 0: 224x224 faux 1.00, vrai 0.00, 34.4ms
# Speed: 3.8ms preprocess, 34.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 195
#
# 0: 224x224 faux 1.00, vrai 0.00, 30.8ms
# Speed: 4.3ms preprocess, 30.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 200
#
# 0: 224x224 faux 1.00, vrai 0.00, 33.8ms
# Speed: 4.9ms preprocess, 33.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 205
#
# 0: 224x224 faux 1.00, vrai 0.00, 36.8ms
# Speed: 4.2ms preprocess, 36.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 210
#
# 0: 224x224 faux 1.00, vrai 0.00, 35.9ms
# Speed: 3.9ms preprocess, 35.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 215
#
# 0: 224x224 faux 1.00, vrai 0.00, 43.1ms
# Speed: 8.4ms preprocess, 43.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 220
#
# 0: 224x224 faux 1.00, vrai 0.00, 110.1ms
# Speed: 8.8ms preprocess, 110.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 0 225
#
# 0: 224x224 faux 1.00, vrai 0.00, 51.1ms
# Speed: 12.3ms preprocess, 51.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 0 230
#
# 0: 224x224 faux 1.00, vrai 0.00, 41.7ms
# Speed: 5.1ms preprocess, 41.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 235
#
# 0: 224x224 faux 1.00, vrai 0.00, 41.3ms
# Speed: 6.3ms preprocess, 41.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 0 240
#
# 0: 224x224 faux 1.00, vrai 0.00, 53.1ms
# Speed: 7.2ms preprocess, 53.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 0 245
#
# 0: 224x224 faux 1.00, vrai 0.00, 48.5ms
# Speed: 5.5ms preprocess, 48.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 0 250
#
# 0: 224x224 faux 1.00, vrai 0.00, 37.0ms
# Speed: 5.2ms preprocess, 37.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 0
#
# 0: 224x224 faux 1.00, vrai 0.00, 39.6ms
# Speed: 4.1ms preprocess, 39.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 5 5
#
# 0: 224x224 faux 1.00, vrai 0.00, 58.3ms
# Speed: 4.2ms preprocess, 58.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 5 10
#
# 0: 224x224 faux 1.00, vrai 0.00, 47.0ms
# Speed: 5.3ms preprocess, 47.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 5 15
#
# 0: 224x224 faux 1.00, vrai 0.00, 34.4ms
# Speed: 5.5ms preprocess, 34.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 5 20
#
# 0: 224x224 faux 1.00, vrai 0.00, 40.1ms
# Speed: 4.2ms preprocess, 40.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 25
#
# 0: 224x224 faux 1.00, vrai 0.00, 37.8ms
# Speed: 4.0ms preprocess, 37.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 30
#
# 0: 224x224 faux 1.00, vrai 0.00, 41.6ms
# Speed: 4.7ms preprocess, 41.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 5 35
#
# 0: 224x224 faux 1.00, vrai 0.00, 36.3ms
# Speed: 5.2ms preprocess, 36.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 40
#
# 0: 224x224 faux 1.00, vrai 0.00, 40.4ms
# Speed: 4.9ms preprocess, 40.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 5 45
#
# 0: 224x224 faux 1.00, vrai 0.00, 30.4ms
# Speed: 5.7ms preprocess, 30.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 50
#
# 0: 224x224 faux 1.00, vrai 0.00, 41.3ms
# Speed: 5.1ms preprocess, 41.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 55
#
# 0: 224x224 faux 1.00, vrai 0.00, 36.4ms
# Speed: 4.5ms preprocess, 36.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 5 60
#
# 0: 224x224 faux 1.00, vrai 0.00, 36.4ms
# Speed: 5.1ms preprocess, 36.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 5 65
#
# 0: 224x224 faux 1.00, vrai 0.00, 33.1ms
# Speed: 4.0ms preprocess, 33.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 70
#
# 0: 224x224 faux 1.00, vrai 0.00, 36.3ms
# Speed: 5.1ms preprocess, 36.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 75
#
# 0: 224x224 faux 1.00, vrai 0.00, 36.3ms
# Speed: 4.2ms preprocess, 36.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 5 80
#
# 0: 224x224 faux 1.00, vrai 0.00, 37.6ms
# Speed: 4.3ms preprocess, 37.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 85
#
# 0: 224x224 faux 1.00, vrai 0.00, 64.0ms
# Speed: 64.2ms preprocess, 64.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 5 90
#
# 0: 224x224 faux 1.00, vrai 0.00, 54.1ms
# Speed: 4.4ms preprocess, 54.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 5 95
#
# 0: 224x224 faux 1.00, vrai 0.00, 38.5ms
# Speed: 4.0ms preprocess, 38.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 100
#
# 0: 224x224 faux 1.00, vrai 0.00, 27.2ms
# Speed: 4.0ms preprocess, 27.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 105
#
# 0: 224x224 faux 1.00, vrai 0.00, 33.6ms
# Speed: 4.6ms preprocess, 33.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 110
#
# 0: 224x224 faux 1.00, vrai 0.00, 33.3ms
# Speed: 4.3ms preprocess, 33.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 115
#
# 0: 224x224 faux 1.00, vrai 0.00, 37.2ms
# Speed: 4.8ms preprocess, 37.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 120
#
# 0: 224x224 faux 1.00, vrai 0.00, 36.5ms
# Speed: 5.1ms preprocess, 36.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 125
#
# 0: 224x224 faux 1.00, vrai 0.00, 44.1ms
# Speed: 4.9ms preprocess, 44.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 5 130
#
# 0: 224x224 faux 1.00, vrai 0.00, 28.4ms
# Speed: 4.9ms preprocess, 28.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 135
#
# 0: 224x224 faux 1.00, vrai 0.00, 32.6ms
# Speed: 4.2ms preprocess, 32.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 140
#
# 0: 224x224 faux 1.00, vrai 0.00, 32.3ms
# Speed: 4.4ms preprocess, 32.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 145
#
# 0: 224x224 faux 1.00, vrai 0.00, 32.6ms
# Speed: 5.2ms preprocess, 32.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 150
#
# 0: 224x224 faux 1.00, vrai 0.00, 30.8ms
# Speed: 3.9ms preprocess, 30.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 155
#
# 0: 224x224 faux 1.00, vrai 0.00, 28.3ms
# Speed: 4.0ms preprocess, 28.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 160
#
# 0: 224x224 faux 1.00, vrai 0.00, 31.6ms
# Speed: 3.7ms preprocess, 31.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 165
#
# 0: 224x224 faux 1.00, vrai 0.00, 32.8ms
# Speed: 4.2ms preprocess, 32.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 170
#
# 0: 224x224 faux 1.00, vrai 0.00, 50.9ms
# Speed: 3.7ms preprocess, 50.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 175
#
# 0: 224x224 faux 1.00, vrai 0.00, 41.2ms
# Speed: 7.0ms preprocess, 41.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 180
#
# 0: 224x224 faux 1.00, vrai 0.00, 52.1ms
# Speed: 6.4ms preprocess, 52.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 5 185
#
# 0: 224x224 faux 1.00, vrai 0.00, 35.8ms
# Speed: 7.3ms preprocess, 35.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 190
#
# 0: 224x224 faux 1.00, vrai 0.00, 40.3ms
# Speed: 4.4ms preprocess, 40.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 195
#
# 0: 224x224 faux 1.00, vrai 0.00, 39.2ms
# Speed: 4.7ms preprocess, 39.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 5 200
#
# 0: 224x224 faux 1.00, vrai 0.00, 39.1ms
# Speed: 4.2ms preprocess, 39.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 5 205
#
# 0: 224x224 faux 1.00, vrai 0.00, 30.3ms
# Speed: 3.8ms preprocess, 30.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 210
#
# 0: 224x224 faux 1.00, vrai 0.00, 34.1ms
# Speed: 4.3ms preprocess, 34.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 215
#
# 0: 224x224 faux 1.00, vrai 0.00, 38.1ms
# Speed: 4.5ms preprocess, 38.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 220
#
# 0: 224x224 faux 1.00, vrai 0.00, 41.3ms
# Speed: 6.6ms preprocess, 41.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 5 225
#
# 0: 224x224 faux 1.00, vrai 0.00, 39.3ms
# Speed: 7.3ms preprocess, 39.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 230
#
# 0: 224x224 faux 1.00, vrai 0.00, 37.5ms
# Speed: 5.5ms preprocess, 37.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 235
#
# 0: 224x224 faux 1.00, vrai 0.00, 34.5ms
# Speed: 4.2ms preprocess, 34.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 240
#
# 0: 224x224 faux 1.00, vrai 0.00, 32.1ms
# Speed: 4.4ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 245
#
# 0: 224x224 faux 1.00, vrai 0.00, 37.9ms
# Speed: 3.9ms preprocess, 37.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 5 250
#
# 0: 224x224 faux 1.00, vrai 0.00, 30.4ms
# Speed: 4.4ms preprocess, 30.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 0
#
# 0: 224x224 faux 1.00, vrai 0.00, 30.7ms
# Speed: 3.9ms preprocess, 30.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 5
#
# 0: 224x224 faux 1.00, vrai 0.00, 31.5ms
# Speed: 4.1ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 10
#
# 0: 224x224 faux 1.00, vrai 0.00, 30.4ms
# Speed: 4.1ms preprocess, 30.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 15
#
# 0: 224x224 faux 1.00, vrai 0.00, 31.1ms
# Speed: 3.4ms preprocess, 31.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 20
#
# 0: 224x224 faux 1.00, vrai 0.00, 34.4ms
# Speed: 4.4ms preprocess, 34.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 25
#
# 0: 224x224 faux 1.00, vrai 0.00, 28.2ms
# Speed: 4.0ms preprocess, 28.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 30
#
# 0: 224x224 faux 1.00, vrai 0.00, 35.0ms
# Speed: 3.5ms preprocess, 35.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 35
#
# 0: 224x224 faux 1.00, vrai 0.00, 37.7ms
# Speed: 4.8ms preprocess, 37.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 40
#
# 0: 224x224 faux 1.00, vrai 0.00, 38.9ms
# Speed: 4.2ms preprocess, 38.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 45
#
# 0: 224x224 faux 1.00, vrai 0.00, 35.0ms
# Speed: 4.6ms preprocess, 35.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 50
#
# 0: 224x224 faux 1.00, vrai 0.00, 38.2ms
# Speed: 4.6ms preprocess, 38.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 55
#
# 0: 224x224 faux 1.00, vrai 0.00, 39.5ms
# Speed: 3.7ms preprocess, 39.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 60
#
# 0: 224x224 faux 1.00, vrai 0.00, 39.7ms
# Speed: 8.0ms preprocess, 39.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 65
#
# 0: 224x224 faux 1.00, vrai 0.00, 44.6ms
# Speed: 4.1ms preprocess, 44.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 70
#
# 0: 224x224 faux 1.00, vrai 0.00, 39.5ms
# Speed: 4.9ms preprocess, 39.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 75
#
# 0: 224x224 faux 1.00, vrai 0.00, 44.4ms
# Speed: 3.8ms preprocess, 44.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 80
#
# 0: 224x224 faux 1.00, vrai 0.00, 39.0ms
# Speed: 4.5ms preprocess, 39.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 85
#
# 0: 224x224 faux 1.00, vrai 0.00, 37.9ms
# Speed: 4.8ms preprocess, 37.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 90
#
# 0: 224x224 faux 1.00, vrai 0.00, 31.7ms
# Speed: 4.1ms preprocess, 31.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 95
#
# 0: 224x224 faux 1.00, vrai 0.00, 39.6ms
# Speed: 5.1ms preprocess, 39.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 100
#
# 0: 224x224 faux 1.00, vrai 0.00, 42.5ms
# Speed: 5.0ms preprocess, 42.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 105
#
# 0: 224x224 faux 1.00, vrai 0.00, 41.6ms
# Speed: 5.6ms preprocess, 41.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 110
#
# 0: 224x224 faux 1.00, vrai 0.00, 27.3ms
# Speed: 4.2ms preprocess, 27.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 115
#
# 0: 224x224 faux 1.00, vrai 0.00, 31.4ms
# Speed: 4.6ms preprocess, 31.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 120
#
# 0: 224x224 faux 1.00, vrai 0.00, 31.3ms
# Speed: 4.3ms preprocess, 31.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 125
#
# 0: 224x224 faux 1.00, vrai 0.00, 35.0ms
# Speed: 4.2ms preprocess, 35.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 130
#
# 0: 224x224 faux 1.00, vrai 0.00, 30.7ms
# Speed: 4.2ms preprocess, 30.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 135
#
# 0: 224x224 faux 1.00, vrai 0.00, 31.8ms
# Speed: 3.8ms preprocess, 31.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 140
#
# 0: 224x224 faux 1.00, vrai 0.00, 33.2ms
# Speed: 4.0ms preprocess, 33.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 145
#
# 0: 224x224 faux 1.00, vrai 0.00, 34.9ms
# Speed: 4.1ms preprocess, 34.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 150
#
# 0: 224x224 faux 1.00, vrai 0.00, 33.6ms
# Speed: 3.8ms preprocess, 33.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 155
#
# 0: 224x224 faux 1.00, vrai 0.00, 26.6ms
# Speed: 4.0ms preprocess, 26.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 160
#
# 0: 224x224 faux 1.00, vrai 0.00, 35.8ms
# Speed: 4.7ms preprocess, 35.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 165
#
# 0: 224x224 faux 1.00, vrai 0.00, 42.2ms
# Speed: 4.5ms preprocess, 42.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 170
#
# 0: 224x224 faux 1.00, vrai 0.00, 39.2ms
# Speed: 4.7ms preprocess, 39.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 175
#
# 0: 224x224 faux 1.00, vrai 0.00, 43.8ms
# Speed: 4.5ms preprocess, 43.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 180
#
# 0: 224x224 faux 1.00, vrai 0.00, 40.5ms
# Speed: 4.3ms preprocess, 40.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 10 185
#
# 0: 224x224 faux 1.00, vrai 0.00, 42.1ms
# Speed: 4.6ms preprocess, 42.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 10 190
#
# 0: 224x224 faux 1.00, vrai 0.00, 38.3ms
# Speed: 4.8ms preprocess, 38.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 10 195
#
# 0: 224x224 faux 1.00, vrai 0.00, 36.3ms
# Speed: 3.7ms preprocess, 36.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 200
#
# 0: 224x224 faux 1.00, vrai 0.00, 38.9ms
# Speed: 5.0ms preprocess, 38.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 205
#
# 0: 224x224 faux 1.00, vrai 0.00, 37.6ms
# Speed: 4.5ms preprocess, 37.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 210
#
# 0: 224x224 faux 1.00, vrai 0.00, 34.4ms
# Speed: 5.1ms preprocess, 34.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 215
#
# 0: 224x224 faux 1.00, vrai 0.00, 33.1ms
# Speed: 4.1ms preprocess, 33.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 220
#
# 0: 224x224 faux 1.00, vrai 0.00, 32.9ms
# Speed: 4.6ms preprocess, 32.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 225
#
# 0: 224x224 faux 1.00, vrai 0.00, 37.4ms
# Speed: 3.9ms preprocess, 37.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 230
#
# 0: 224x224 faux 1.00, vrai 0.00, 32.2ms
# Speed: 4.3ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 235
#
# 0: 224x224 faux 1.00, vrai 0.00, 32.2ms
# Speed: 4.2ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 240
#
# 0: 224x224 faux 1.00, vrai 0.00, 31.7ms
# Speed: 4.3ms preprocess, 31.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 245
#
# 0: 224x224 faux 1.00, vrai 0.00, 25.6ms
# Speed: 4.7ms preprocess, 25.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 10 250
#
# 0: 224x224 faux 1.00, vrai 0.00, 27.1ms
# Speed: 3.8ms preprocess, 27.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 0
#
# 0: 224x224 faux 1.00, vrai 0.00, 31.1ms
# Speed: 4.1ms preprocess, 31.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 5
#
# 0: 224x224 faux 1.00, vrai 0.00, 29.8ms
# Speed: 3.8ms preprocess, 29.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 10
#
# 0: 224x224 faux 1.00, vrai 0.00, 30.4ms
# Speed: 3.8ms preprocess, 30.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 15
#
# 0: 224x224 faux 1.00, vrai 0.00, 30.9ms
# Speed: 3.7ms preprocess, 30.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 20
#
# 0: 224x224 faux 1.00, vrai 0.00, 27.1ms
# Speed: 3.5ms preprocess, 27.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 25
#
# 0: 224x224 faux 1.00, vrai 0.00, 30.3ms
# Speed: 3.6ms preprocess, 30.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 30
#
# 0: 224x224 faux 1.00, vrai 0.00, 30.9ms
# Speed: 4.0ms preprocess, 30.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 35
#
# 0: 224x224 faux 1.00, vrai 0.00, 32.4ms
# Speed: 4.4ms preprocess, 32.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 40
#
# 0: 224x224 faux 1.00, vrai 0.00, 34.2ms
# Speed: 7.5ms preprocess, 34.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 15 45
#
# 0: 224x224 faux 1.00, vrai 0.00, 40.9ms
# Speed: 4.5ms preprocess, 40.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 50
#
# 0: 224x224 faux 1.00, vrai 0.00, 44.1ms
# Speed: 4.8ms preprocess, 44.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 55
#
# 0: 224x224 faux 1.00, vrai 0.00, 41.9ms
# Speed: 6.6ms preprocess, 41.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 60
#
# 0: 224x224 faux 1.00, vrai 0.00, 41.2ms
# Speed: 6.6ms preprocess, 41.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 65
#
# 0: 224x224 faux 1.00, vrai 0.00, 36.9ms
# Speed: 5.2ms preprocess, 36.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 70
#
# 0: 224x224 faux 1.00, vrai 0.00, 34.4ms
# Speed: 4.5ms preprocess, 34.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 75
#
# 0: 224x224 faux 1.00, vrai 0.00, 38.1ms
# Speed: 3.5ms preprocess, 38.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 80
#
# 0: 224x224 faux 1.00, vrai 0.00, 40.5ms
# Speed: 7.0ms preprocess, 40.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 15 85
#
# 0: 224x224 faux 1.00, vrai 0.00, 49.1ms
# Speed: 6.9ms preprocess, 49.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 15 90
#
# 0: 224x224 faux 1.00, vrai 0.00, 41.6ms
# Speed: 6.1ms preprocess, 41.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 95
#
# 0: 224x224 faux 1.00, vrai 0.00, 33.2ms
# Speed: 5.9ms preprocess, 33.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 100
#
# 0: 224x224 faux 1.00, vrai 0.00, 46.4ms
# Speed: 4.0ms preprocess, 46.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 105
#
# 0: 224x224 faux 1.00, vrai 0.00, 47.2ms
# Speed: 4.5ms preprocess, 47.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 110
#
# 0: 224x224 faux 1.00, vrai 0.00, 40.3ms
# Speed: 6.3ms preprocess, 40.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 115
#
# 0: 224x224 faux 1.00, vrai 0.00, 38.5ms
# Speed: 9.1ms preprocess, 38.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 120
#
# 0: 224x224 faux 1.00, vrai 0.00, 34.2ms
# Speed: 3.9ms preprocess, 34.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 125
#
# 0: 224x224 faux 1.00, vrai 0.00, 45.0ms
# Speed: 5.1ms preprocess, 45.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 130
#
# 0: 224x224 faux 1.00, vrai 0.00, 52.3ms
# Speed: 7.5ms preprocess, 52.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 135
#
# 0: 224x224 faux 1.00, vrai 0.00, 46.7ms
# Speed: 4.4ms preprocess, 46.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 15 140
#
# 0: 224x224 faux 1.00, vrai 0.00, 36.1ms
# Speed: 6.0ms preprocess, 36.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 15 145
#
# 0: 224x224 faux 1.00, vrai 0.00, 40.4ms
# Speed: 6.4ms preprocess, 40.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 150
#
# 0: 224x224 faux 1.00, vrai 0.00, 39.4ms
# Speed: 6.4ms preprocess, 39.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 155
#
# 0: 224x224 faux 1.00, vrai 0.00, 42.1ms
# Speed: 5.8ms preprocess, 42.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 15 160
#
# 0: 224x224 faux 1.00, vrai 0.00, 46.9ms
# Speed: 6.6ms preprocess, 46.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 15 165
#
# 0: 224x224 faux 1.00, vrai 0.00, 35.1ms
# Speed: 3.8ms preprocess, 35.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 15 170
#
# 0: 224x224 faux 1.00, vrai 0.00, 34.0ms
# Speed: 4.9ms preprocess, 34.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 175
#
# 0: 224x224 faux 1.00, vrai 0.00, 42.9ms
# Speed: 6.6ms preprocess, 42.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 180
#
# 0: 224x224 faux 1.00, vrai 0.00, 33.4ms
# Speed: 3.7ms preprocess, 33.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 185
#
# 0: 224x224 faux 1.00, vrai 0.00, 34.0ms
# Speed: 4.2ms preprocess, 34.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 15 190
#
# 0: 224x224 faux 1.00, vrai 0.00, 37.5ms
# Speed: 4.4ms preprocess, 37.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 195
#
# 0: 224x224 faux 1.00, vrai 0.00, 32.0ms
# Speed: 3.4ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 200
#
# 0: 224x224 faux 1.00, vrai 0.00, 40.9ms
# Speed: 4.7ms preprocess, 40.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 15 205
#
# 0: 224x224 faux 1.00, vrai 0.00, 41.3ms
# Speed: 4.5ms preprocess, 41.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 210
#
# 0: 224x224 faux 1.00, vrai 0.00, 44.3ms
# Speed: 5.2ms preprocess, 44.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 15 215
#
# 0: 224x224 faux 1.00, vrai 0.00, 33.8ms
# Speed: 6.9ms preprocess, 33.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 220
#
# 0: 224x224 faux 1.00, vrai 0.00, 38.1ms
# Speed: 4.2ms preprocess, 38.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 15 225
#
# 0: 224x224 faux 1.00, vrai 0.00, 29.3ms
# Speed: 4.5ms preprocess, 29.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 230
#
# 0: 224x224 faux 1.00, vrai 0.00, 39.7ms
# Speed: 4.9ms preprocess, 39.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 235
#
# 0: 224x224 faux 1.00, vrai 0.00, 43.8ms
# Speed: 4.6ms preprocess, 43.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 15 240
#
# 0: 224x224 faux 1.00, vrai 0.00, 32.5ms
# Speed: 4.5ms preprocess, 32.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 245
#
# 0: 224x224 faux 1.00, vrai 0.00, 34.7ms
# Speed: 4.3ms preprocess, 34.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 15 250
#
# 0: 224x224 faux 1.00, vrai 0.00, 38.6ms
# Speed: 6.8ms preprocess, 38.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 0
#
# 0: 224x224 faux 1.00, vrai 0.00, 37.6ms
# Speed: 6.4ms preprocess, 37.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 20 5
#
# 0: 224x224 faux 1.00, vrai 0.00, 41.1ms
# Speed: 5.4ms preprocess, 41.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 20 10
#
# 0: 224x224 faux 1.00, vrai 0.00, 35.7ms
# Speed: 5.2ms preprocess, 35.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 15
#
# 0: 224x224 faux 1.00, vrai 0.00, 37.9ms
# Speed: 5.1ms preprocess, 37.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 20 20
#
# 0: 224x224 faux 1.00, vrai 0.00, 33.5ms
# Speed: 4.4ms preprocess, 33.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 25
#
# 0: 224x224 faux 1.00, vrai 0.00, 29.5ms
# Speed: 4.7ms preprocess, 29.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 30
#
# 0: 224x224 faux 1.00, vrai 0.00, 33.9ms
# Speed: 3.9ms preprocess, 33.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 35
#
# 0: 224x224 faux 1.00, vrai 0.00, 34.1ms
# Speed: 4.2ms preprocess, 34.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 40
#
# 0: 224x224 faux 1.00, vrai 0.00, 34.7ms
# Speed: 3.5ms preprocess, 34.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 45
#
# 0: 224x224 faux 1.00, vrai 0.00, 43.8ms
# Speed: 9.4ms preprocess, 43.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 50
#
# 0: 224x224 faux 1.00, vrai 0.00, 31.9ms
# Speed: 3.8ms preprocess, 31.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 55
#
# 0: 224x224 faux 1.00, vrai 0.00, 28.7ms
# Speed: 3.7ms preprocess, 28.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 60
#
# 0: 224x224 faux 1.00, vrai 0.00, 33.6ms
# Speed: 4.0ms preprocess, 33.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 65
#
# 0: 224x224 faux 1.00, vrai 0.00, 32.5ms
# Speed: 4.0ms preprocess, 32.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 70
#
# 0: 224x224 faux 1.00, vrai 0.00, 28.5ms
# Speed: 4.0ms preprocess, 28.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 20 75
#
# 0: 224x224 faux 1.00, vrai 0.00, 26.6ms
# Speed: 4.5ms preprocess, 26.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 20 80
#
# 0: 224x224 faux 1.00, vrai 0.00, 24.7ms
# Speed: 4.3ms preprocess, 24.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 85
#
# 0: 224x224 faux 1.00, vrai 0.00, 24.2ms
# Speed: 3.9ms preprocess, 24.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 90
#
# 0: 224x224 faux 1.00, vrai 0.00, 24.5ms
# Speed: 3.8ms preprocess, 24.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 95
#
# 0: 224x224 faux 1.00, vrai 0.00, 24.7ms
# Speed: 3.8ms preprocess, 24.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 100
#
# 0: 224x224 faux 1.00, vrai 0.00, 25.6ms
# Speed: 3.9ms preprocess, 25.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 105
#
# 0: 224x224 faux 1.00, vrai 0.00, 26.5ms
# Speed: 3.8ms preprocess, 26.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 110
#
# 0: 224x224 faux 1.00, vrai 0.00, 26.0ms
# Speed: 4.1ms preprocess, 26.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 115
#
# 0: 224x224 faux 1.00, vrai 0.00, 24.4ms
# Speed: 3.7ms preprocess, 24.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 120
#
# 0: 224x224 faux 1.00, vrai 0.00, 28.8ms
# Speed: 3.7ms preprocess, 28.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 125
#
# 0: 224x224 faux 1.00, vrai 0.00, 26.1ms
# Speed: 3.8ms preprocess, 26.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 130
#
# 0: 224x224 faux 1.00, vrai 0.00, 27.3ms
# Speed: 3.7ms preprocess, 27.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 135
#
# 0: 224x224 faux 1.00, vrai 0.00, 39.5ms
# Speed: 6.9ms preprocess, 39.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 140
#
# 0: 224x224 faux 1.00, vrai 0.00, 36.8ms
# Speed: 5.9ms preprocess, 36.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 145
#
# 0: 224x224 faux 1.00, vrai 0.00, 34.4ms
# Speed: 6.6ms preprocess, 34.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 20 150
#
# 0: 224x224 faux 1.00, vrai 0.00, 34.5ms
# Speed: 4.6ms preprocess, 34.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 155
#
# 0: 224x224 faux 1.00, vrai 0.00, 51.1ms
# Speed: 3.9ms preprocess, 51.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 20 160
#
# 0: 224x224 faux 1.00, vrai 0.00, 37.3ms
# Speed: 6.9ms preprocess, 37.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 165
#
# 0: 224x224 faux 1.00, vrai 0.00, 38.7ms
# Speed: 5.3ms preprocess, 38.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 170
#
# 0: 224x224 faux 1.00, vrai 0.00, 37.4ms
# Speed: 5.1ms preprocess, 37.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 20 175
#
# 0: 224x224 faux 1.00, vrai 0.00, 45.6ms
# Speed: 5.2ms preprocess, 45.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 20 180
#
# 0: 224x224 faux 1.00, vrai 0.00, 33.4ms
# Speed: 6.2ms preprocess, 33.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 185
#
# 0: 224x224 faux 1.00, vrai 0.00, 58.3ms
# Speed: 7.0ms preprocess, 58.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 20 190
#
# 0: 224x224 faux 1.00, vrai 0.00, 53.2ms
# Speed: 6.4ms preprocess, 53.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 20 195
#
# 0: 224x224 faux 1.00, vrai 0.00, 38.4ms
# Speed: 4.0ms preprocess, 38.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 200
#
# 0: 224x224 faux 1.00, vrai 0.00, 41.6ms
# Speed: 4.6ms preprocess, 41.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 20 205
#
# 0: 224x224 faux 1.00, vrai 0.00, 60.7ms
# Speed: 5.1ms preprocess, 60.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 20 210
#
# 0: 224x224 faux 1.00, vrai 0.00, 44.3ms
# Speed: 5.1ms preprocess, 44.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 20 215
#
# 0: 224x224 faux 1.00, vrai 0.00, 36.4ms
# Speed: 7.7ms preprocess, 36.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 20 220
#
# 0: 224x224 faux 1.00, vrai 0.00, 38.4ms
# Speed: 4.2ms preprocess, 38.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 225
#
# 0: 224x224 faux 1.00, vrai 0.00, 38.6ms
# Speed: 4.3ms preprocess, 38.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 20 230
#
# 0: 224x224 faux 1.00, vrai 0.00, 36.9ms
# Speed: 3.7ms preprocess, 36.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 235
#
# 0: 224x224 faux 1.00, vrai 0.00, 41.8ms
# Speed: 4.8ms preprocess, 41.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 20 240
#
# 0: 224x224 faux 1.00, vrai 0.00, 36.9ms
# Speed: 5.0ms preprocess, 36.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 20 245
#
# 0: 224x224 faux 1.00, vrai 0.00, 39.2ms
# Speed: 5.5ms preprocess, 39.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 20 250
#
# 0: 224x224 faux 1.00, vrai 0.00, 30.5ms
# Speed: 5.8ms preprocess, 30.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 0
#
# 0: 224x224 faux 1.00, vrai 0.00, 26.0ms
# Speed: 4.3ms preprocess, 26.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 5
#
# 0: 224x224 faux 1.00, vrai 0.00, 38.2ms
# Speed: 4.3ms preprocess, 38.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 10
#
# 0: 224x224 faux 1.00, vrai 0.00, 40.0ms
# Speed: 6.3ms preprocess, 40.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 15
#
# 0: 224x224 faux 1.00, vrai 0.00, 45.9ms
# Speed: 4.1ms preprocess, 45.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 25 20
#
# 0: 224x224 faux 1.00, vrai 0.00, 42.3ms
# Speed: 4.3ms preprocess, 42.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 25
#
# 0: 224x224 faux 1.00, vrai 0.00, 40.2ms
# Speed: 4.3ms preprocess, 40.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 25 30
#
# 0: 224x224 faux 1.00, vrai 0.00, 38.5ms
# Speed: 4.0ms preprocess, 38.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 25 35
#
# 0: 224x224 faux 1.00, vrai 0.00, 33.5ms
# Speed: 4.5ms preprocess, 33.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 25 40
#
# 0: 224x224 faux 1.00, vrai 0.00, 29.0ms
# Speed: 4.6ms preprocess, 29.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 45
#
# 0: 224x224 faux 1.00, vrai 0.00, 31.4ms
# Speed: 4.0ms preprocess, 31.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 50
#
# 0: 224x224 faux 1.00, vrai 0.00, 30.8ms
# Speed: 3.8ms preprocess, 30.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 55
#
# 0: 224x224 faux 1.00, vrai 0.00, 32.5ms
# Speed: 3.9ms preprocess, 32.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 60
#
# 0: 224x224 faux 1.00, vrai 0.00, 36.5ms
# Speed: 4.2ms preprocess, 36.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 65
#
# 0: 224x224 faux 1.00, vrai 0.00, 35.4ms
# Speed: 3.9ms preprocess, 35.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 70
#
# 0: 224x224 faux 1.00, vrai 0.00, 43.0ms
# Speed: 4.4ms preprocess, 43.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 75
#
# 0: 224x224 faux 1.00, vrai 0.00, 53.7ms
# Speed: 6.1ms preprocess, 53.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 25 80
#
# 0: 224x224 faux 1.00, vrai 0.00, 61.3ms
# Speed: 4.7ms preprocess, 61.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 25 85
#
# 0: 224x224 faux 1.00, vrai 0.00, 34.0ms
# Speed: 5.9ms preprocess, 34.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 25 90
#
# 0: 224x224 faux 1.00, vrai 0.00, 40.5ms
# Speed: 4.6ms preprocess, 40.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 25 95
#
# 0: 224x224 faux 1.00, vrai 0.00, 39.4ms
# Speed: 4.2ms preprocess, 39.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 100
#
# 0: 224x224 faux 1.00, vrai 0.00, 45.6ms
# Speed: 4.1ms preprocess, 45.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 105
#
# 0: 224x224 faux 1.00, vrai 0.00, 44.4ms
# Speed: 5.2ms preprocess, 44.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 110
#
# 0: 224x224 faux 1.00, vrai 0.00, 43.6ms
# Speed: 8.3ms preprocess, 43.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 115
#
# 0: 224x224 faux 1.00, vrai 0.00, 34.4ms
# Speed: 5.4ms preprocess, 34.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 120
#
# 0: 224x224 faux 1.00, vrai 0.00, 38.3ms
# Speed: 5.7ms preprocess, 38.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 125
#
# 0: 224x224 faux 1.00, vrai 0.00, 37.6ms
# Speed: 4.4ms preprocess, 37.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 25 130
#
# 0: 224x224 faux 1.00, vrai 0.00, 32.6ms
# Speed: 4.1ms preprocess, 32.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 25 135
#
# 0: 224x224 faux 1.00, vrai 0.00, 32.6ms
# Speed: 4.3ms preprocess, 32.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 140
#
# 0: 224x224 faux 1.00, vrai 0.00, 35.5ms
# Speed: 4.5ms preprocess, 35.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 145
#
# 0: 224x224 faux 1.00, vrai 0.00, 33.0ms
# Speed: 4.4ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 150
#
# 0: 224x224 faux 1.00, vrai 0.00, 25.4ms
# Speed: 3.6ms preprocess, 25.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 155
#
# 0: 224x224 faux 1.00, vrai 0.00, 33.2ms
# Speed: 3.4ms preprocess, 33.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 160
#
# 0: 224x224 faux 1.00, vrai 0.00, 34.3ms
# Speed: 4.4ms preprocess, 34.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 165
#
# 0: 224x224 faux 1.00, vrai 0.00, 29.8ms
# Speed: 3.4ms preprocess, 29.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 170
#
# 0: 224x224 faux 1.00, vrai 0.00, 35.0ms
# Speed: 4.1ms preprocess, 35.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 175
#
# 0: 224x224 faux 1.00, vrai 0.00, 28.8ms
# Speed: 4.6ms preprocess, 28.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 180
#
# 0: 224x224 faux 1.00, vrai 0.00, 32.7ms
# Speed: 4.4ms preprocess, 32.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 185
#
# 0: 224x224 faux 1.00, vrai 0.00, 33.8ms
# Speed: 4.1ms preprocess, 33.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 190
#
# 0: 224x224 faux 1.00, vrai 0.00, 31.9ms
# Speed: 3.8ms preprocess, 31.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 195
#
# 0: 224x224 faux 1.00, vrai 0.00, 33.2ms
# Speed: 4.1ms preprocess, 33.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 200
#
# 0: 224x224 faux 1.00, vrai 0.00, 32.9ms
# Speed: 4.3ms preprocess, 32.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 205
#
# 0: 224x224 faux 1.00, vrai 0.00, 33.0ms
# Speed: 4.1ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 210
#
# 0: 224x224 faux 1.00, vrai 0.00, 32.3ms
# Speed: 3.6ms preprocess, 32.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 215
#
# 0: 224x224 faux 1.00, vrai 0.00, 34.8ms
# Speed: 4.1ms preprocess, 34.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 220
#
# 0: 224x224 faux 1.00, vrai 0.00, 48.5ms
# Speed: 4.1ms preprocess, 48.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 225
#
# 0: 224x224 faux 1.00, vrai 0.00, 40.5ms
# Speed: 5.8ms preprocess, 40.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 25 230
#
# 0: 224x224 faux 1.00, vrai 0.00, 88.2ms
# Speed: 8.9ms preprocess, 88.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 25 235
#
# 0: 224x224 faux 1.00, vrai 0.00, 33.4ms
# Speed: 5.0ms preprocess, 33.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 25 240
#
# 0: 224x224 faux 1.00, vrai 0.00, 38.5ms
# Speed: 4.6ms preprocess, 38.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 25 245
#
# 0: 224x224 faux 1.00, vrai 0.00, 27.3ms
# Speed: 3.7ms preprocess, 27.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 25 250
#
# 0: 224x224 faux 1.00, vrai 0.00, 44.5ms
# Speed: 4.1ms preprocess, 44.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 30 0
#
# 0: 224x224 faux 1.00, vrai 0.00, 36.7ms
# Speed: 10.0ms preprocess, 36.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 30 5
#
# 0: 224x224 faux 1.00, vrai 0.00, 32.6ms
# Speed: 4.3ms preprocess, 32.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 30 10
#
# 0: 224x224 faux 1.00, vrai 0.00, 31.2ms
# Speed: 4.2ms preprocess, 31.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 30 15
#
# 0: 224x224 faux 1.00, vrai 0.00, 31.7ms
# Speed: 4.0ms preprocess, 31.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 30 20
#
# 0: 224x224 faux 1.00, vrai 0.00, 35.6ms
# Speed: 4.0ms preprocess, 35.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 30 25
#
# 0: 224x224 faux 1.00, vrai 0.00, 31.1ms
# Speed: 3.6ms preprocess, 31.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 30 30
#
# 0: 224x224 faux 1.00, vrai 0.00, 31.3ms
# Speed: 3.9ms preprocess, 31.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 30 35
#
# 0: 224x224 faux 1.00, vrai 0.00, 39.4ms
# Speed: 7.7ms preprocess, 39.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 30 40
#
# 0: 224x224 faux 1.00, vrai 0.00, 35.8ms
# Speed: 5.8ms preprocess, 35.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 30 45
#
# 0: 224x224 faux 1.00, vrai 0.00, 37.8ms
# Speed: 3.9ms preprocess, 37.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 30 50
#
# 0: 224x224 faux 1.00, vrai 0.00, 35.2ms
# Speed: 4.8ms preprocess, 35.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 30 55
#
# 0: 224x224 faux 1.00, vrai 0.00, 28.2ms
# Speed: 6.6ms preprocess, 28.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 30 60
#
# 0: 224x224 faux 1.00, vrai 0.00, 34.8ms
# Speed: 4.0ms preprocess, 34.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 30 65
#
# 0: 224x224 faux 1.00, vrai 0.00, 34.8ms
# Speed: 4.3ms preprocess, 34.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 30 70
#
# 0: 224x224 faux 1.00, vrai 0.00, 39.2ms
# Speed: 4.3ms preprocess, 39.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 30 75
#
# 0: 224x224 faux 1.00, vrai 0.00, 38.9ms
# Speed: 4.8ms preprocess, 38.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 30 80
#
# 0: 224x224 faux 1.00, vrai 0.00, 33.4ms
# Speed: 4.6ms preprocess, 33.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 30 85
#
# 0: 224x224 faux 1.00, vrai 0.00, 33.2ms
# Speed: 4.5ms preprocess, 33.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 30 90
#
# 0: 224x224 faux 1.00, vrai 0.00, 40.2ms
# Speed: 3.9ms preprocess, 40.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 30 95
#
# 0: 224x224 faux 1.00, vrai 0.00, 42.2ms
# Speed: 4.6ms preprocess, 42.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 30 100
#
# 0: 224x224 faux 1.00, vrai 0.00, 63.0ms
# Speed: 6.7ms preprocess, 63.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 30 105
#
# 0: 224x224 faux 1.00, vrai 0.00, 26.6ms
# Speed: 4.8ms preprocess, 26.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 30 110
#
# 0: 224x224 faux 1.00, vrai 0.00, 28.3ms
# Speed: 3.7ms preprocess, 28.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 30 115
#
# 0: 224x224 faux 1.00, vrai 0.00, 31.0ms
# Speed: 4.1ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 30 120
#
# 0: 224x224 faux 1.00, vrai 0.00, 35.0ms
# Speed: 3.9ms preprocess, 35.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 30 125
#
# 0: 224x224 faux 1.00, vrai 0.00, 30.0ms
# ...
# 105 20
#
# 0: 224x224 faux 0.91, vrai 0.09, 33.9ms
# Speed: 4.5ms preprocess, 33.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 25
#
# 0: 224x224 faux 0.92, vrai 0.08, 35.9ms
# Speed: 4.3ms preprocess, 35.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 30
#
# 0: 224x224 faux 0.91, vrai 0.09, 35.3ms
# Speed: 4.2ms preprocess, 35.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 35
#
# 0: 224x224 faux 0.91, vrai 0.09, 32.9ms
# Speed: 4.1ms preprocess, 32.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 40
#
# 0: 224x224 faux 0.91, vrai 0.09, 36.6ms
# Speed: 4.3ms preprocess, 36.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 45
#
# 0: 224x224 faux 0.91, vrai 0.09, 29.7ms
# Speed: 3.8ms preprocess, 29.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 50
#
# 0: 224x224 faux 0.91, vrai 0.09, 40.0ms
# Speed: 4.5ms preprocess, 40.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 55
#
# 0: 224x224 faux 0.91, vrai 0.09, 41.3ms
# Speed: 3.9ms preprocess, 41.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 60
#
# 0: 224x224 faux 0.91, vrai 0.09, 31.7ms
# Speed: 4.2ms preprocess, 31.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 65
#
# 0: 224x224 faux 0.91, vrai 0.09, 40.0ms
# Speed: 3.5ms preprocess, 40.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 70
#
# 0: 224x224 faux 0.91, vrai 0.09, 32.9ms
# Speed: 4.3ms preprocess, 32.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 105 75
#
# 0: 224x224 faux 0.91, vrai 0.09, 35.9ms
# Speed: 3.8ms preprocess, 35.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 80
#
# 0: 224x224 faux 0.91, vrai 0.09, 34.8ms
# Speed: 4.0ms preprocess, 34.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 85
#
# 0: 224x224 faux 0.91, vrai 0.09, 35.3ms
# Speed: 3.8ms preprocess, 35.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 90
#
# 0: 224x224 faux 0.91, vrai 0.09, 35.3ms
# Speed: 4.7ms preprocess, 35.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 95
#
# 0: 224x224 faux 0.91, vrai 0.09, 25.6ms
# Speed: 4.1ms preprocess, 25.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 100
#
# 0: 224x224 faux 0.91, vrai 0.09, 39.8ms
# Speed: 4.6ms preprocess, 39.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 105
#
# 0: 224x224 faux 0.91, vrai 0.09, 34.6ms
# Speed: 3.8ms preprocess, 34.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 110
#
# 0: 224x224 faux 0.91, vrai 0.09, 29.9ms
# Speed: 4.2ms preprocess, 29.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 115
#
# 0: 224x224 faux 0.91, vrai 0.09, 34.3ms
# Speed: 5.4ms preprocess, 34.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 120
#
# 0: 224x224 faux 0.91, vrai 0.09, 34.6ms
# Speed: 4.3ms preprocess, 34.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 125
#
# 0: 224x224 faux 0.91, vrai 0.09, 31.8ms
# Speed: 4.5ms preprocess, 31.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 105 130
#
# 0: 224x224 faux 0.91, vrai 0.09, 32.0ms
# Speed: 4.7ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 135
#
# 0: 224x224 faux 0.91, vrai 0.09, 27.7ms
# Speed: 4.6ms preprocess, 27.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 140
#
# 0: 224x224 faux 0.91, vrai 0.09, 34.5ms
# Speed: 4.0ms preprocess, 34.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 145
#
# 0: 224x224 faux 0.91, vrai 0.09, 37.1ms
# Speed: 4.8ms preprocess, 37.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 150
#
# 0: 224x224 faux 0.91, vrai 0.09, 34.5ms
# Speed: 3.5ms preprocess, 34.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 155
#
# 0: 224x224 faux 0.91, vrai 0.09, 43.7ms
# Speed: 4.2ms preprocess, 43.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 105 160
#
# 0: 224x224 faux 0.91, vrai 0.09, 29.2ms
# Speed: 4.1ms preprocess, 29.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 165
#
# 0: 224x224 faux 0.91, vrai 0.09, 31.8ms
# Speed: 5.0ms preprocess, 31.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 170
#
# 0: 224x224 faux 0.91, vrai 0.09, 32.9ms
# Speed: 3.8ms preprocess, 32.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 175
#
# 0: 224x224 faux 0.91, vrai 0.09, 35.5ms
# Speed: 4.1ms preprocess, 35.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 105 180
#
# 0: 224x224 faux 0.91, vrai 0.09, 28.5ms
# Speed: 4.6ms preprocess, 28.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 185
#
# 0: 224x224 faux 0.91, vrai 0.09, 35.2ms
# Speed: 4.0ms preprocess, 35.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 190
#
# 0: 224x224 faux 0.91, vrai 0.09, 39.2ms
# Speed: 4.2ms preprocess, 39.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 195
#
# 0: 224x224 faux 0.91, vrai 0.09, 32.5ms
# Speed: 4.5ms preprocess, 32.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 200
#
# 0: 224x224 faux 0.91, vrai 0.09, 33.0ms
# Speed: 4.1ms preprocess, 33.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 105 205
#
# 0: 224x224 faux 0.91, vrai 0.09, 27.1ms
# Speed: 4.2ms preprocess, 27.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 210
#
# 0: 224x224 faux 0.91, vrai 0.09, 35.4ms
# Speed: 3.8ms preprocess, 35.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 215
#
# 0: 224x224 faux 0.91, vrai 0.09, 27.0ms
# Speed: 4.3ms preprocess, 27.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 220
#
# 0: 224x224 faux 0.91, vrai 0.09, 32.6ms
# Speed: 4.1ms preprocess, 32.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 225
#
# 0: 224x224 faux 0.91, vrai 0.09, 28.1ms
# Speed: 4.5ms preprocess, 28.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 230
#
# 0: 224x224 faux 0.91, vrai 0.09, 37.3ms
# Speed: 5.7ms preprocess, 37.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 235
#
# 0: 224x224 faux 0.91, vrai 0.09, 29.2ms
# Speed: 3.7ms preprocess, 29.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 240
#
# 0: 224x224 faux 0.91, vrai 0.09, 38.5ms
# Speed: 4.2ms preprocess, 38.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 105 245
#
# 0: 224x224 faux 0.91, vrai 0.09, 43.6ms
# Speed: 4.1ms preprocess, 43.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 105 250
#
# 0: 224x224 faux 0.91, vrai 0.09, 32.9ms
# Speed: 3.7ms preprocess, 32.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 0
#
# 0: 224x224 faux 0.91, vrai 0.09, 32.6ms
# Speed: 4.0ms preprocess, 32.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 5
#
# 0: 224x224 faux 0.91, vrai 0.09, 31.4ms
# Speed: 4.0ms preprocess, 31.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 10
#
# 0: 224x224 faux 0.91, vrai 0.09, 31.0ms
# Speed: 4.0ms preprocess, 31.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 110 15
#
# 0: 224x224 faux 0.91, vrai 0.09, 31.7ms
# Speed: 5.2ms preprocess, 31.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 20
#
# 0: 224x224 faux 0.89, vrai 0.11, 31.0ms
# Speed: 6.2ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 25
#
# 0: 224x224 faux 0.91, vrai 0.09, 30.3ms
# Speed: 6.9ms preprocess, 30.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 30
#
# 0: 224x224 faux 0.91, vrai 0.09, 26.9ms
# Speed: 4.5ms preprocess, 26.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 35
#
# 0: 224x224 faux 0.93, vrai 0.07, 26.0ms
# Speed: 4.4ms preprocess, 26.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 40
#
# 0: 224x224 faux 0.91, vrai 0.09, 32.3ms
# Speed: 4.1ms preprocess, 32.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 45
#
# 0: 224x224 faux 0.91, vrai 0.09, 35.0ms
# Speed: 4.3ms preprocess, 35.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 50
#
# 0: 224x224 faux 0.91, vrai 0.09, 35.7ms
# Speed: 4.7ms preprocess, 35.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 55
#
# 0: 224x224 faux 0.91, vrai 0.09, 26.3ms
# Speed: 4.6ms preprocess, 26.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 60
#
# 0: 224x224 faux 0.91, vrai 0.09, 35.4ms
# Speed: 5.3ms preprocess, 35.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 65
#
# 0: 224x224 faux 0.91, vrai 0.09, 32.6ms
# Speed: 4.3ms preprocess, 32.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 70
#
# 0: 224x224 faux 0.91, vrai 0.09, 31.2ms
# Speed: 4.0ms preprocess, 31.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 75
#
# 0: 224x224 faux 0.91, vrai 0.09, 34.9ms
# Speed: 4.0ms preprocess, 34.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 80
#
# 0: 224x224 faux 0.91, vrai 0.09, 32.2ms
# Speed: 4.3ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 85
#
# 0: 224x224 faux 0.91, vrai 0.09, 29.4ms
# Speed: 5.1ms preprocess, 29.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 90
#
# 0: 224x224 faux 0.91, vrai 0.09, 33.5ms
# Speed: 3.8ms preprocess, 33.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 95
#
# 0: 224x224 faux 0.91, vrai 0.09, 35.7ms
# Speed: 4.5ms preprocess, 35.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 100
#
# 0: 224x224 faux 0.91, vrai 0.09, 33.1ms
# Speed: 4.3ms preprocess, 33.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 105
#
# 0: 224x224 faux 0.91, vrai 0.09, 25.2ms
# Speed: 3.9ms preprocess, 25.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 110
#
# 0: 224x224 faux 0.91, vrai 0.09, 42.4ms
# Speed: 4.4ms preprocess, 42.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 115
#
# 0: 224x224 faux 0.91, vrai 0.09, 41.7ms
# Speed: 4.5ms preprocess, 41.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 120
#
# 0: 224x224 faux 0.91, vrai 0.09, 25.1ms
# Speed: 3.4ms preprocess, 25.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 125
#
# 0: 224x224 faux 0.91, vrai 0.09, 33.6ms
# Speed: 4.0ms preprocess, 33.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 130
#
# 0: 224x224 faux 0.91, vrai 0.09, 34.4ms
# Speed: 4.5ms preprocess, 34.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 135
#
# 0: 224x224 faux 0.91, vrai 0.09, 37.4ms
# Speed: 3.6ms preprocess, 37.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 110 140
#
# 0: 224x224 faux 0.91, vrai 0.09, 39.0ms
# Speed: 4.2ms preprocess, 39.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 145
#
# 0: 224x224 faux 0.91, vrai 0.09, 26.7ms
# Speed: 4.7ms preprocess, 26.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 150
#
# 0: 224x224 faux 0.91, vrai 0.09, 32.5ms
# Speed: 4.1ms preprocess, 32.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 155
#
# 0: 224x224 faux 0.91, vrai 0.09, 32.8ms
# Speed: 4.5ms preprocess, 32.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 160
#
# 0: 224x224 faux 0.91, vrai 0.09, 31.8ms
# Speed: 3.6ms preprocess, 31.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 165
#
# 0: 224x224 faux 0.91, vrai 0.09, 36.1ms
# Speed: 3.9ms preprocess, 36.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 170
#
# 0: 224x224 faux 0.91, vrai 0.09, 31.0ms
# Speed: 4.5ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 175
#
# 0: 224x224 faux 0.91, vrai 0.09, 26.5ms
# Speed: 4.3ms preprocess, 26.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 180
#
# 0: 224x224 faux 0.91, vrai 0.09, 37.8ms
# Speed: 4.8ms preprocess, 37.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 185
#
# 0: 224x224 faux 0.91, vrai 0.09, 32.4ms
# Speed: 3.8ms preprocess, 32.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 190
#
# 0: 224x224 faux 0.91, vrai 0.09, 33.1ms
# Speed: 4.0ms preprocess, 33.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 195
#
# 0: 224x224 faux 0.91, vrai 0.09, 31.4ms
# Speed: 4.4ms preprocess, 31.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 200
#
# 0: 224x224 faux 0.91, vrai 0.09, 32.9ms
# Speed: 4.1ms preprocess, 32.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 110 205
#
# 0: 224x224 faux 0.91, vrai 0.09, 36.0ms
# Speed: 4.2ms preprocess, 36.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 210
#
# 0: 224x224 faux 0.91, vrai 0.09, 36.2ms
# Speed: 4.2ms preprocess, 36.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 215
#
# 0: 224x224 faux 0.91, vrai 0.09, 32.4ms
# Speed: 4.7ms preprocess, 32.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 220
#
# 0: 224x224 faux 0.91, vrai 0.09, 31.9ms
# Speed: 3.8ms preprocess, 31.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 225
#
# 0: 224x224 faux 0.91, vrai 0.09, 25.7ms
# Speed: 4.7ms preprocess, 25.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 230
#
# 0: 224x224 faux 0.91, vrai 0.09, 36.2ms
# Speed: 4.5ms preprocess, 36.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 235
#
# 0: 224x224 faux 0.91, vrai 0.09, 37.8ms
# Speed: 4.5ms preprocess, 37.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 240
#
# 0: 224x224 faux 0.91, vrai 0.09, 27.3ms
# Speed: 4.6ms preprocess, 27.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 245
#
# 0: 224x224 faux 0.91, vrai 0.09, 34.7ms
# Speed: 4.0ms preprocess, 34.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 110 250
#
# 0: 224x224 faux 0.91, vrai 0.09, 39.5ms
# Speed: 4.7ms preprocess, 39.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 115 0
#
# 0: 224x224 faux 0.91, vrai 0.09, 40.2ms
# Speed: 7.1ms preprocess, 40.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 115 5
#
# 0: 224x224 faux 0.91, vrai 0.09, 25.4ms
# Speed: 3.5ms preprocess, 25.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 115 10
#
# 0: 224x224 faux 0.91, vrai 0.09, 31.9ms
# Speed: 4.0ms preprocess, 31.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 115 15
#
# 0: 224x224 faux 0.91, vrai 0.09, 35.1ms
# Speed: 3.8ms preprocess, 35.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 115 20
#
# 0: 224x224 faux 0.90, vrai 0.10, 34.4ms
# Speed: 4.1ms preprocess, 34.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 115 25
#
# 0: 224x224 faux 0.92, vrai 0.08, 37.1ms
# Speed: 4.5ms preprocess, 37.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 115 30
#
# 0: 224x224 faux 0.92, vrai 0.08, 33.2ms
# Speed: 5.4ms preprocess, 33.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 115 35
#
# 0: 224x224 faux 0.91, vrai 0.09, 27.7ms
# Speed: 3.7ms preprocess, 27.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 115 40
#
# 0: 224x224 faux 0.91, vrai 0.09, 34.5ms
# Speed: 4.5ms preprocess, 34.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 115 45
#
# 0: 224x224 faux 0.92, vrai 0.08, 32.3ms
# Speed: 4.6ms preprocess, 32.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 115 50
#
# 0: 224x224 faux 0.91, vrai 0.09, 29.2ms
# Speed: 5.4ms preprocess, 29.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 115 55
#
# 0: 224x224 faux 0.91, vrai 0.09, 43.3ms

# %%
plt.imshow(heatmap,cmap='jet')
plt.colorbar()
plt.show()

# %%
def overlay_heatmap(image,heatmap,alpha=0.5) :
    heatmap_normalize = (heatmap - np.min(heatmap)) / (np.max(heatmap) - np.min(heatmap))
    heatmap_colored=cv2.applyColorMap(np.uint8(255*heatmap_normalize),cv2.COLORMAP_JET)
    
    overlay=cv2.addWeighted(image,alpha,heatmap_colored,1-alpha,0)
    return overlay

# %%
f, axes = plt.subplots(1,2, figsize=(10,15))
overlay_image=overlay_heatmap(image,heatmap)
axes[0].imshow(cv2.cvtColor(overlay_image,cv2.COLOR_BGR2RGB))
axes[1].imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))

plt.show()

# %%
cv2.imwrite(f'yolo/occlusion/occlusion_{image_path.split("/")[-1]}',overlay_image)
# Out:
# True
